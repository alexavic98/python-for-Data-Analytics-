# %% [markdown]
# importing the necessary libraries

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.jumia.com.ng/catalog/?q=iphones"
response = requests.get(url)
response = response.content
response
# Out:
# b'<!DOCTYPE html><html lang="en" dir="ltr"><head><meta charset="utf-8"/><title>Shop All Products - TVs, Laptops, Fashion Items | Jumia Nigeria</title><meta property="og:type" content="product"/><meta property="og:site_name" content="Jumia Nigeria"/><meta property="og:title" content="Shop All Products - TVs, Laptops, Fashion Items | Jumia Nigeria"/><meta property="og:description" content="Enjoy amazing discounts and deals up to 70% on your favourite iPhones, android devices, TVs, Cookers and more offers at the best prices on Jumia Nigeria."/><meta property="og:url" content="/catalog/"/><meta property="og:image" content="https://ng.jumia.is/cms/jumialogonew.png"/><meta property="og:locale" content="en_NG"/><meta name="title" content="Shop All Products - TVs, Laptops, Fashion Items | Jumia Nigeria"/><meta name="robots" content="noindex,follow"/><meta name="description" content="Enjoy amazing discounts and deals up to 70% on your favourite iPhones, android devices, TVs, Cookers and more offers at the best prices on Jumia Nigeria."/><link rel="alternate" href="android-app://com.jumia.android/JUMIA/NG/s/iphones?utm_source=google&amp;utm_medium=organic&amp;adjust_tracker=j1hd8h&amp;adjust_campaign=GOOGLE_SEARCH&amp;adjust_adgroup=https%3A%2F%2Fwww.jumia.com.ng%2Fcatalog%2F%3Fq%3Diphones"/><link rel="canonical" href="https://www.jumia.com.ng/flash-sales"/><link rel="next" href="https://www.jumia.com.ng/catalog/?q=iphones&amp;page=2"/><meta property="fb:app_id" content="728795990650684"/><meta property="fb:pages" content="291297097615087"/><meta name="google-site-verification" content="4vr0StQ8YkyEzgDxkC_mgx0UMSH2xM3vkOaRpaMEjWM"/><meta name="google-site-verification" content="VeavdmtsHUH8fIEGpu4eeF-ryLp5ZXVUOmWmXWzV11I"/><meta name="msvalidate.01" content="66DCE7076C4C56245BAB83C687510491"/><meta name="viewport" content="width=device-width, initial-scale=1.0"/><link rel="stylesheet" href="https://www.jumia.com.ng/assets_he/css/main.9cf344e4.css"/><link rel="icon" type="image/ico" sizes="any" href="https://www.jumia.com.ng/assets_he/favicon.87f00114.ico"/><link rel="icon" type="image/svg+xml" href="https://www.jumia.com.ng/assets_he/favicon.adbd556a.svg"/><link rel="preconnect dns-prefetch" href="//bam.nr-data.net"/><link rel="preconnect dns-prefetch" href="//js-agent.newrelic.com"/><link rel="preconnect dns-prefetch" href="//www.google-analytics.com"/><link rel="preconnect dns-prefetch" href="//www.googletagmanager.com"/><link rel="preconnect dns-prefetch" href="//www.facebook.com"/><link rel="preconnect dns-prefetch" href="//connect.facebook.net"/><link rel="preconnect dns-prefetch" href="//static.criteo.net"/><link rel="preconnect dns-prefetch" href="//sslwidget.criteo.com"/><link rel="preconnect dns-prefetch" href="//dis.eu.criteo.com"/><link rel="preconnect dns-prefetch" href="//creativecdn.com"/><link rel="dns-prefetch" href="https://ng.jumia.is"/></head><body><script type=\'text/javascript\'>window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"b76de0635f","applicationID":"202020352","agentToken":null,"applicationTime":19.972363,"transactionName":"NVxXYhMHChFYVUELDQwWdkMSEgsPFnVUFgMOVlIWHUY0LWpi","queueTime":0,"ttGuid":"87212316ee4a4240"}; (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"b76de0635f",applicationID:"202020352"};;/*! For license information please see nr-loader-rum-1.249.0.min.js.LICENSE.txt */\n(()=>{var e,t,r={234:(e,t,r)=>{"use strict";r.d(t,{P_:()=>v,Mt:()=>b,C5:()=>s,DL:()=>A,OP:()=>S,lF:()=>T,Yu:()=>x,Dg:()=>m,CX:()=>c,GE:()=>_,sU:()=>R});var n=r(8632),i=r(9567);const a={beacon:n.ce.beacon,errorBeacon:n.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},o={ ...

# %%
phones = []

soup = BeautifulSoup(response, "html.parser")

div = soup.find("div", class_="-paxs row _no-g _4cl-3cm-shs" )
articles = div.find_all("article", class_="prd _fb col c-prd")

# %%
for article in articles:
    items = article.find("div", class_ = "info")
    names = items.find("h3", class_= "name").text
    # text was added to return only the text in that tag. i.e getting rid of all other unwanted elements
    #print(names)
    price = items.find("div",class_="prc").text
    price = price[1:]
    # this line ((price = price[1:])) was added to return the values from the first index and above. i.e leaving out the 0 index
    price = price[1:]
    # this line ((price = float(price[1:])) can be added to convert the price from a str to a float
    #print(names)
    items_old_price = article.find("div", class_="prc")
    old_price = items_old_price.find("div", class_="old")
    #old_price = old_price[1:]
    old_price

    #lets create a list that contains the phone name, price and old price
    
    phones.append([names, price, old_price])
    phones

# %% [markdown]
# lets create a list that contains the phone name, price and old price

# %%
import pandas as pd
pd.DataFrame(phones, columns=["names", "price", "old_price"])
phones


#phones.to_csv("jumia phones.csv")
# Out:
# [['Apple IPhone 14 Pro Max 6.7" 256GB Nano Sim - Deep Purple',
#   '1,600,000',
#   None],
#  ['IPhone X 64GB - （Renewed）- Silver - 5.8 Inch', '218,000', None],
#  ['Apple IPhone 13 Pro 6.1 Inch (6GB RAM + 256GB ROM)- Blue',
#   '1,000,000',
#   None],
#  ['DUAL Type-c Wireless Lapel Microphone For IPhone & Android + IOS Adapter',
#   '13,700',
#   None],
#  ['Apple IPhone 13 Pro Max 6.7" Super Retina XDR Display With ProMotion, (6GB RAM + 128GB ROM) IOS 15, 5G, FaceTime - Sierra Blue',
#   '940,000',
#   None],
#  ['K9 Dual Wireless Microphone For IPhone & Android + IOS Adapter(Double Mic)',
#   '11,995',
#   None],
#  ['IPhone X 3GB RAM+64GB(Renewed)  -Black', '219,800', None],
#  ['IPhone 7 Plus 32GB+RAM3GB(Renewed-)-Black IPhone7P', '139,900', None],
#  ['For IPhone & Android + IOS Adapter Single Type-c Wireless Lapel Microphone',
#   '9,500',
#   None],
#  ['IPhone 6S Plus 16GB(Refurbished) -Silver (Grade A)', '89,500', None],
#  ['IPhone 6S Plus 64GB(Refurbished )-Gold Grade A', '110,098', None],
#  ['IPhone 6S Plus 16GB(Refurbished) -Rose Gold (Grade A)', '89,500', None],
#  ['Apple IPhone 12, 6.1-Inch 128GB ROM 5G  - Pacific Blue', '478,000', None],
#  ['IPhone 6S Plus 16GB(Refurbished) -Gold (Grade A)', '89,500', None],
#  ['Apple IPhone 12, 6.1-Inch, 64GB ROM 4GB RAM, 5G - Pacific Blue',
#   '449,000',
#   None],
#  ['IPhone 6S Plus 2GB RAM+64GB(Refurbished ) -Silver (Grade A)',
#   '110,098',
#   None],
#  ['Apple IPhone 15 Pro 128GB White Titanium - FaceTime - A17 Pro Chip',
#   '1,440,999',
#   None],
#  ['Wireless Lapel Microphone Type-c For IPhone Android IPad', '16,000', None],
#  ['50W Dual Type C Lighting Super Fast Original Charger For Iphone 15/5pro/15promax/14 Pro Max/14 Plus/14/13 Pro Max/13 Pro/13/13 Mini/12 Pro Max/12 Pro/12/12 Mini/11 Pro Max/11 Pro/11 And Ipads',
#   '4,995',
#   None],
#  ['Apple IPhone XR - 6.1 Inches - 64GB ROM - 3GB RAM - 4G LTE - Red - With Free Pouch & Screen Guide',
#   '301,000',
#   None],
#  ['Apple Iphone XS Max 256gb 4gb 6.5" Gold, Free Case & Screen Guide',
#   '329,000',
#   None],
#  ['Apple IPhone 11 Pro Max 6.5-Inch (4GB RAM, 256GB ROM),iOS 13, (12MP+12MP+12MP)+12MP 4G LTE Smartphone - Midnight Green',
#   '594,500',
#   None],
#  ['Apple IPHONE 12 - 6.1" 64GB 4GB RAM (12PM+12PM) 2815mAh RED',
#   '449,000',
#   None],
#  ['K9 Dual Wireless Microphone For IPhone & Android + IOS Adapter(Double Mic)',
#   '11,995',
#   None],
#  ['Apple IPHONE 11 - 6.1"  64/4GB RAM (12MP+12MP) 3110mAh PURPLE',
#   '354,500',
#   None],
#  ['20W Type C Fast Charger For IPhone 14/13/12/11/XR/ Pro Max', '5,400', None],
#  ['15W Fast Wireless Charger For Samsung IPhone Android', '6,550', None],
#  ['Apple Iphone XR 64gb 3gb 6.1inch Yellow Free Case & Screen Guide',
#   '301,000',
#   None],
#  ['IPhone 6 Plus 16GB (Refurbished ) - Gold (Grade A)', '51,500', None],
#  ['Apple IPhone 11 6.1-Inch Liquid Retina LCD (4GB RAM, 64GB ROM) IOS 13, (12MP+12MP)+12MP 4G LTE Smartphone - White',
#   '354,500',
#   None],
#  ['Apple Iphone XR 128gb 3gb 6.1inch White Free Case & Screen Guide',
#   '320,000',
#   None],
#  ['Apple IPhone XS Max 256GB Silver, Free Case And Screen Guide',
#   '375,000',
#   None],
#  ['IPhone 6 Fingerprint 4G LTE 64G 4.7" Refurbished Smartphone',
#   '60,000',
#   None],
#  ['Apple Iphone XS Max 256gb 4gb 6.5inch Silver Free Case, Screen Guide',
#   '375,000',
#   None],
#  ['Apple IPhone XS Max - 6.5" - 256GB RAM - 4GB ROM - IOS 12 - 4G Smartphone - 3174mAh - Silver + Free Pouch And Screen Protector',
#   '375,000',
#   None],
#  ['Apple Iphone XR 128gb 3gb 6.1" White, Case & Screen Guide',
#   '320,000',
#   None],
#  ['Apple Iphone XS Max 256gb Space Grey, Free Pouch And Screen Protector',
#   '375,000',
#   None],
#  ['BOMGE Wireless Lavalier Microphone, With Charging Case For IPhone And Android',
#   '14,376',
#   None],
#  ['Apple Iphone XR 128gb 3gb Ram Blue, Free Case & Screen Guide',
#   '320,000',
#   None],
#  ['Iphone Pro Max Series 25W Type C Super-Fast Charger', '4,999', None]]
